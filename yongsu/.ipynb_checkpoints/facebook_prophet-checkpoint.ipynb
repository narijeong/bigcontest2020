# %%
import pandas as pd
import matplotlib.pyplot as plt
from fbprophet import Prophet

# %%
sales_train = pd.read_excel('/content/sales_train_final.xlsx',encoding="CP949")
sales_train.head()
# Out:
#    Unnamed: 0                방송일시  ...  coincident_index       w_prime
# 0           0 2019-01-01 06:00:00  ...             100.2  4.771683e+07
# 1           1 2019-01-01 06:00:00  ...             100.2  4.771683e+07
# 2           2 2019-01-01 06:20:00  ...             100.2  4.771683e+07
# 3           3 2019-01-01 06:20:00  ...             100.2  4.771683e+07
# 4           4 2019-01-01 06:40:00  ...             100.2  4.771683e+07
#
# [5 rows x 38 columns]

# %% [markdown]
# ## 시계열 예측을 위한 Facebook prophet, x축 - 방송일시, y축 - 취급액

# %%
def prophet_analy(df,category):
  print(i)
  df = df[['방송일시','취급액']]

  df2 = pd.DataFrame(index=range(0,0), columns=['ds', 'y'])
  df2['ds'] = df['방송일시']
  df2['y'] = df['취급액']

 # 일별, 주별 시계열 plot
  m = Prophet()
  m.fit(df2)

  future = m.make_future_dataframe(periods=365)
  
  forecast = m.predict(future)
  #forecast.iloc[-365:, :].yhat.plot()

  fig1 = m.plot(forecast, uncertainty=False)
  plt.show()

  fig2 = m.plot_components(forecast)
  plt.show()

  # 월별 시계열 plot을 보기 위해 추가
  m = Prophet(weekly_seasonality=False)
  m.add_seasonality(name='monthly', period=30.5, fourier_order=5)
  forecast = m.fit(df2).predict(future)

  fig = m.plot_components(forecast)

# %% [markdown]
# ## 상품군 전체에 대한 1년간 일,주,월 시계열 plot

# %%
prophet_analy(sales_train,'전체')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 전체
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# ## 상품군 별 1년 간 일,주,월 시계열 plot
# ## 상품군 인코딩 클래스
# ## ['가구' '가전' '건강기능' '농수축' '생활용품' '속옷' '의류' '이미용' '잡화' '주방' '침구']

# %%
prophet_analy(sales_train[sales_train['상품군']==0],'가구')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 가구
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
prophet_analy(sales_train[sales_train['상품군']==1],'가전')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 가전
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
sales_train[sales_train['상품군']==1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-23c411d83bfd> in <module>
# ----> 1 sales_train[sales_train['상품군']==1]
#
# NameError: name 'sales_train' is not defined

# %%
prophet_analy(sales_train[sales_train['상품군']==2],'건강기능')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 건강기능
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
prophet_analy(sales_train[sales_train['상품군']==3],'농수축')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 농수축
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
prophet_analy(sales_train[sales_train['상품군']==4],'생활용품')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 생활용품
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
prophet_analy(sales_train[sales_train['상품군']==5],'속옷')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 속옷
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
prophet_analy(sales_train[sales_train['상품군']==6],'의류')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 의류
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
prophet_analy(sales_train[sales_train['상품군']==7],'이미용')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 이미용
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
prophet_analy(sales_train[sales_train['상품군']==8],'잡화')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 잡화
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
prophet_analy(sales_train[sales_train['상품군']==9],'침구')
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# 침구
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
